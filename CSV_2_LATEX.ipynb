# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
# Load CSV
path = "./outputs/output_german_credit_standard.csv"
df = pd.read_csv(path)
df = df.drop(['Dataset', 'Variant'], axis=1)

latex_table = df.to_latex(index=False)

# Wrap in a complete LaTeX table 
wrapped_latex_table = r"""
\begin{table}[!htbp]
    \centering
    \scalebox{0.37}{
""" + latex_table + r"""
    }
    \caption{}
    \label{}
\end{table}
"""

print(wrapped_latex_table)
# Out:
# \begin{table}[!htbp]
#     \centering
#     \scalebox{0.37}{
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrr}
# \toprule
# Noise Level & model &  accuracy &  precision &  R19 Compl &  BR19 (Mean) Compl &  BR19 (Marg) Compl &  DiCE Compl &  NICE Compl &  RL Compl &      R19 L1 &  BR19 (Mean) L1 &  BR19 (Marg) L1 &   DiCE L1 &   NICE L1 &      RL L1 &      R19 L2 &  BR19 (Mean) L2 &  BR19 (Marg) L2 &   DiCE L2 &   NICE L2 &      RL L2 \\
# \midrule
#     noise\_0 &   blr &  0.769697 &   0.758851 &        NaN &           1.000000 &                NaN &         NaN &         NaN &       NaN &         NaN &        0.000000 &             NaN &       NaN &       NaN &        NaN &         NaN &        0.000000 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_0 &    lr &  0.769697 &   0.758851 &   1.000000 &                NaN &                NaN &    1.000000 &         1.0 &  0.878788 &    0.000000 &             NaN &             NaN &  9.388822 &  8.686609 &  74.386073 &    0.000000 &             NaN &             NaN &  4.486761 &  4.136250 &  66.334704 \\
#     noise\_0 &    rf &  0.754545 &   0.742734 &        NaN &                NaN &                NaN &    0.978788 &         1.0 &  0.218182 &         NaN &             NaN &             NaN &  9.144693 &  9.453771 &  39.463920 &         NaN &             NaN &             NaN &  4.339037 &  4.360463 &  30.965744 \\
#     noise\_0 &    tf &  0.754545 &   0.747971 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN &  0.000000 &  0.000000 &        NaN &         NaN &             NaN &             NaN &  0.000000 &  0.000000 &        NaN \\
#     noise\_1 &   blr &  0.733333 &   0.719766 &        NaN &           0.966667 &                NaN &         NaN &         NaN &       NaN &         NaN &     1840.435837 &             NaN &       NaN &       NaN &        NaN &         NaN &     1816.279161 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_1 &    lr &  0.730303 &   0.715612 &   0.966667 &                NaN &                NaN &    1.000000 &         1.0 &  0.996970 & 1840.477318 &             NaN &             NaN & 32.983895 & 31.658988 & 144.351630 & 1816.279524 &             NaN &             NaN & 11.651861 & 11.250856 & 125.990582 \\
#     noise\_1 &    rf &  0.703030 &   0.675330 &        NaN &                NaN &                NaN &    0.981818 &         1.0 &  1.000000 &         NaN &             NaN &             NaN & 32.448184 & 32.702923 &  81.698858 &         NaN &             NaN &             NaN & 11.538470 & 11.543340 &  47.662222 \\
#     noise\_1 &    tf &  0.675758 &   0.654277 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN & 32.271338 & 32.271338 &        NaN &         NaN &             NaN &             NaN & 12.048512 & 12.048512 &        NaN \\
#     noise\_2 &   blr &  0.639394 &   0.575691 &        NaN &           1.000000 &                NaN &         NaN &         NaN &       NaN &         NaN &      437.117541 &             NaN &       NaN &       NaN &        NaN &         NaN &      395.846094 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_2 &    lr &  0.639394 &   0.575691 &   1.000000 &                NaN &                NaN &    1.000000 &         1.0 &  0.130303 &  437.216884 &             NaN &             NaN & 47.827227 & 45.685311 &  60.482492 &  395.848898 &             NaN &             NaN & 13.857808 & 13.594529 &  30.010323 \\
#     noise\_2 &    rf &  0.663636 &   0.599540 &        NaN &                NaN &                NaN &    0.978788 &         1.0 &  0.054545 &         NaN &             NaN &             NaN & 47.013261 & 47.694175 &  96.997083 &         NaN &             NaN &             NaN & 14.117852 & 14.294867 &  54.934998 \\
#     noise\_2 &    tf &  0.651515 &   0.620205 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN & 48.592802 & 48.592802 &        NaN &         NaN &             NaN &             NaN & 14.979850 & 14.979850 &        NaN \\
#     noise\_3 &   blr &  0.645455 &   0.572022 &        NaN &           1.000000 &                NaN &         NaN &         NaN &       NaN &         NaN &      475.445057 &             NaN &       NaN &       NaN &        NaN &         NaN &      425.202502 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_3 &    lr &  0.642424 &   0.568596 &   1.000000 &                NaN &                NaN &    1.000000 &         1.0 &  0.121212 &  475.435719 &             NaN &             NaN & 53.978945 & 51.501781 &  66.689323 &  425.202799 &             NaN &             NaN & 14.739194 & 14.566347 &  33.024238 \\
#     noise\_3 &    rf &  0.672727 &   0.589288 &        NaN &                NaN &                NaN &    0.996970 &         1.0 &  0.315152 &         NaN &             NaN &             NaN & 53.638981 & 52.039478 & 132.272463 &         NaN &             NaN &             NaN & 14.613841 & 14.478971 &  97.367219 \\
#     noise\_3 &    tf &  0.603030 &   0.582723 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN & 54.020206 & 54.020206 &        NaN &         NaN &             NaN &             NaN & 14.938836 & 14.938836 &        NaN \\
#     noise\_4 &   blr &  0.630303 &   0.550635 &        NaN &           1.000000 &                NaN &         NaN &         NaN &       NaN &         NaN &      455.891245 &             NaN &       NaN &       NaN &        NaN &         NaN &      405.643539 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_4 &    lr &  0.627273 &   0.545949 &   1.000000 &                NaN &                NaN &    1.000000 &         1.0 &  0.912121 &  455.898648 &             NaN &             NaN & 55.795941 & 52.799093 &  33.680223 &  405.643569 &             NaN &             NaN & 14.825904 & 14.592280 &  13.742209 \\
#     noise\_4 &    rf &  0.645455 &   0.534261 &        NaN &                NaN &                NaN &    0.993939 &         1.0 &  1.000000 &         NaN &             NaN &             NaN & 55.052033 & 52.676170 & 226.206047 &         NaN &             NaN &             NaN & 14.740197 & 14.713689 & 181.144901 \\
#     noise\_4 &    tf &  0.618182 &   0.585929 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN & 54.448516 & 54.448516 &        NaN &         NaN &             NaN &             NaN & 14.983557 & 14.983557 &        NaN \\
#     noise\_5 &   blr &  0.630303 &   0.565044 &        NaN &           0.430303 &                NaN &         NaN &         NaN &       NaN &         NaN &      340.903497 &             NaN &       NaN &       NaN &        NaN &         NaN &      290.891762 &             NaN &       NaN &       NaN &        NaN \\
#     noise\_5 &    lr &  0.630303 &   0.565044 &   0.424242 &                NaN &                NaN &    1.000000 &         1.0 &  1.000000 & 7071.212783 &             NaN &             NaN & 57.272873 & 54.033858 &  42.776089 & 7019.947697 &             NaN &             NaN & 15.308852 & 15.414275 &  17.560418 \\
#     noise\_5 &    rf &  0.645455 &   0.576134 &        NaN &                NaN &                NaN &    0.993939 &         1.0 &  0.030303 &         NaN &             NaN &             NaN & 55.483454 & 52.596771 &  57.976630 &         NaN &             NaN &             NaN & 14.831618 & 14.750446 &  34.859554 \\
#     noise\_5 &    tf &  0.596970 &   0.538702 &        NaN &                NaN &                NaN &    1.000000 &         1.0 &       NaN &         NaN &             NaN &             NaN & 55.654418 & 55.654418 &        NaN &         NaN &             NaN &             NaN & 15.383905 & 15.383905 &        NaN \\
# \bottomrule
# \end{tabular}
#
#     }
#     \caption{}
#     \label{}
# \end{table}
